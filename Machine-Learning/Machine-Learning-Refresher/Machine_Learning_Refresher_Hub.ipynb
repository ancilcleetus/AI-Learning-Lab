# %% [markdown]
# # **Machine Learning Refresher Hub**

# %% [markdown]
# ![rainbow](https://raw.githubusercontent.com/ancilcleetus/AI-Learning-Lab/main/assets/rainbow-divider.png)

# %% [markdown]
# # 📖 TABLE OF CONTENTS
#
# - [Setup](#Setup)
# - [What is Machine Learning?](#What-is-Machine-Learning?)
#   - [Supervised Learning](#Supervised-Learning)
# - [References](#References)

# %% [markdown]
# ![rainbow](https://raw.githubusercontent.com/ancilcleetus/AI-Learning-Lab/main/assets/rainbow-divider.png)

# %% [markdown]
# # Setup

# %% [markdown]
# Before we jump in, let's quickly run the setup cell. It checks the environment (GPU, library versions) and sets random seeds for reproducibility — we want identical results on every run.

# %%
# 🔧 Setup: Run this cell first!
# Environment check + random seeds for reproducibility

import sys
import time
import random
import numpy as np
import pandas as pd
import matplotlib as mpl
import torch
import torch.nn as nn

print(f"📦 Python  {sys.version.split()[0]}")
print(f"🔢 NumPy   {np.__version__}")
print(f"📊 Matplotlib   {mpl.__version__}")
print(f"🔥 PyTorch {torch.__version__}")

# GPU check (only needed for optional deep-feature experiments)
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"✅ GPU available: {torch.cuda.get_device_name(0)}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    device = torch.device("cpu")
    print("⚠️ No GPU detected")

DEVICE_LABEL = "GPU" if device.type == "cuda" else "CPU"

# Random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print(f"\n🎲 Random seed set to {SEED} (Python, NumPy, PyTorch)")

# %matplotlib inline
# %config InlineBackend.figure_format = 'jpeg'   # photos as JPEG, not PNG — ~10× smaller notebook
# Remove character limits for all columns of Pandas dataframes permanently in this session
pd.set_option('display.max_colwidth', None)
# Out:
# 📦 Python  3.12.13
# 🔢 NumPy   2.0.2
# 📊 Matplotlib   3.10.0
# 🔥 PyTorch 2.11.0+cpu
# ⚠️ No GPU detected
#
# 🎲 Random seed set to 42 (Python, NumPy, PyTorch)

# %% [markdown]
# ![rainbow](https://raw.githubusercontent.com/ancilcleetus/AI-Learning-Lab/main/assets/rainbow-divider.png)

# %% [markdown]
# # What is Machine Learning?

# %% [markdown]
# In traditional programming paradigms, we write explicit rules to achieve our objectives. In Machine Learning, we let the computer learn patterns from data (from examples) and use those patterns to make predictions on unseen data; just like humans learn to recognize cats by seeing many cats.
#
# Traditional Programming vs Machine Learning:
# * Traditional Programming $\Rightarrow$ Rules + Data $\rightarrow$ Output
# * Machine Learning $\Rightarrow$ Data + Output $\rightarrow$ Rules
#
# | Type of ML | Data has labels? | Goal | Examples |
# | :--------- | :--------------- | :--- | :------- |
# | Supervised Learning | Yes | Predict outcomes| Predict house prices, Predict hand-written digits |
# | Unsupervised Learning | No | Find hidden structure (clusters, associations, reduced representations) | Customer Segmentation, Anomaly Detection, Data Compression |
# | Reinforcement Learning | Rewards & penalties | Learn best action | Game-playing agents (Go, Chess), Robot navigation/control |

# %% [markdown]
# ## Supervised Learning

# %% [markdown]
# **The analogy:** Like studying with an answer key. You see questions (features) + correct answers (labels).
# The model learns the mapping: INPUT → OUTPUT from thousands of examples.
#
# **How it works:**
# * Training data has BOTH inputs (X) and correct outputs (y)
# * Model learns to predict y from X
# * Two main tasks: Regression (predict a number) & Classification (predict a category)
#
# **Examples:** predicting house prices, spam detection, disease diagnosis

# %% [markdown]
# ![rainbow](https://raw.githubusercontent.com/ancilcleetus/AI-Learning-Lab/main/assets/rainbow-divider.png)

# %% [markdown]
# # References

# %% [markdown]
# - **"Machine Learning Study Notes.pdf"**

# %% [markdown]
# ![rainbow](https://raw.githubusercontent.com/ancilcleetus/AI-Learning-Lab/main/assets/rainbow-divider.png)

# %%
from IPython.display import Image, display, Markdown
display(Image(filename="data/images/Notebook_Template-01.png", width=500))
display(Markdown("*Notebook Template*"))

# %% [markdown]
# ![rainbow](https://raw.githubusercontent.com/ancilcleetus/AI-Learning-Lab/main/assets/rainbow-divider.png)
